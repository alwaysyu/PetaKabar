# %%
import pandas as pd
import re
import string
from flair.models import SequenceTagger


PATH = "D:/Repository/PetaKabar/whowherewhen/"
bencana = "bencana/"
ekonomi = "ekonomi/"
kecelakaan = "kecelakaan/"
kesehatan = "kesehatan/"
kriminalitas = "kriminalitas/"
olahraga = "olahraga/"

model_location = PATH

news = pd.read_csv('perbandingan/berita-24-5.csv')
tag_pos = SequenceTagger.load(model_location + 'best-model.pt')
# Out:
# 2023-06-26 08:28:38,066 SequenceTagger predicts: Dictionary with 20 tags: <unk>, NOUN, PROPN, PUNCT, VERB, ADP, PRON, ADJ, NUM, DET, CCONJ, ADV, AUX, SCONJ, PART, SYM, X, INTJ, <START>, <STOP>

# %%
def preprocessing(berita):
        s = str(berita)
        s = s.replace('\n', ' ')
        s = s.replace('\r', ' ')
        s = s.replace('  ', ' ')
        return s

# %%
from flair.data import Sentence
import joblib
from sklearn.model_selection import train_test_split

iter_through = ['bencana', 'ekonomi', 'kecelakaan', 'kesehatan', 'kriminalitas', 'olahraga']

# Bencana
x = 1
tagged = []
berita = news[news['berita_topik_id'] == x]
df_train, df_test = train_test_split(berita, test_size=0.075, random_state=1)
print(x, len(df_train), len(df_test))

for i in range(len(df_test)):
    text = df_test['berita_desc'].iloc[i]
    preprocessed_text = preprocessing(text)
    sentence = Sentence(preprocessed_text)
    tag_pos.predict(sentence)
    # print(sentence.to_tagged_string())
    tagged.append(sentence)

joblib.dump(tagged, PATH + 'test_tagged_' + iter_through[x-1] + '.pkl')

# Ekonomi
x = 2
tagged = []
berita = news[news['berita_topik_id'] == x]
df_train, df_test = train_test_split(berita, test_size=0.08, random_state=1)
print(x, len(df_train), len(df_test))

for i in range(len(df_test)):
    text = df_test['berita_desc'].iloc[i]
    preprocessed_text = preprocessing(text)
    sentence = Sentence(preprocessed_text)
    tag_pos.predict(sentence)
    # print(sentence.to_tagged_string())
    tagged.append(sentence)

joblib.dump(tagged, PATH + 'test_tagged_' + iter_through[x-1] + '.pkl')

# Kecelakaan
x = 3
tagged = []
berita = news[news['berita_topik_id'] == x]
df_train, df_test = train_test_split(berita, test_size=0.06, random_state=1)
print(x, len(df_train), len(df_test))

for i in range(len(df_test)):
    text = df_test['berita_desc'].iloc[i]
    preprocessed_text = preprocessing(text)
    sentence = Sentence(preprocessed_text)
    tag_pos.predict(sentence)
    # print(sentence.to_tagged_string())
    tagged.append(sentence)

joblib.dump(tagged, PATH + 'test_tagged_' + iter_through[x-1] + '.pkl')

# Kesehatan
x = 4
tagged = []
berita = news[news['berita_topik_id'] == x]
df_train, df_test = train_test_split(berita, test_size=0.11, random_state=1)
print(x, len(df_train), len(df_test))

for i in range(len(df_test)):
    text = df_test['berita_desc'].iloc[i]
    preprocessed_text = preprocessing(text)
    sentence = Sentence(preprocessed_text)
    tag_pos.predict(sentence)
    # print(sentence.to_tagged_string())
    tagged.append(sentence)

joblib.dump(tagged, PATH + 'test_tagged_' + iter_through[x-1] + '.pkl')

# Kriminalitas
x = 5
tagged = []
berita = news[news['berita_topik_id'] == x]
df_train, df_test = train_test_split(berita, test_size=0.1, random_state=1)
print(x, len(df_train), len(df_test))

for i in range(len(df_test)):
    text = df_test['berita_desc'].iloc[i]
    preprocessed_text = preprocessing(text)
    sentence = Sentence(preprocessed_text)
    tag_pos.predict(sentence)
    # print(sentence.to_tagged_string())
    tagged.append(sentence)

joblib.dump(tagged, PATH + 'test_tagged_' + iter_through[x-1] + '.pkl')

# Olahraga
x = 6
tagged = []
berita = news[news['berita_topik_id'] == x]
df_train, df_test = train_test_split(berita, test_size=0.1, random_state=1)
print(x, len(df_train), len(df_test))

for i in range(len(df_test)):
    text = df_test['berita_desc'].iloc[i]
    preprocessed_text = preprocessing(text)
    sentence = Sentence(preprocessed_text)
    tag_pos.predict(sentence)
    # print(sentence.to_tagged_string())
    tagged.append(sentence)

joblib.dump(tagged, PATH + 'test_tagged_' + iter_through[x-1] + '.pkl')
# Out:
# 1 2565 208
# 2 2889 252
# 3 1975 127
# 4 1165 144
# 5 2231 248
# 6 440 49
# ['D:/Repository/PetaKabar/whowherewhen/test_tagged_olahraga.pkl']

# %%
# CREATE PICKLE of TAGGED

from flair.data import Sentence
import joblib

len_docs = 110
start = 0
# len_docs = len(news)
# print(len_docs)



iter_through = ['bencana', 'ekonomi', 'kecelakaan', 'kesehatan', 'kriminalitas', 'olahraga']

for topik_id, n in enumerate(iter_through):
    tagged = []
    berita = news[news['berita_topik_id'] == topik_id]
    # find date
    for i in range(start, start+len_docs):
        text = berita['berita_desc'].iloc[i]
        preprocessed_text = preprocessing(text)
        sentence = Sentence(preprocessed_text)
        tag_pos.predict(sentence)
        print(sentence.to_tagged_string())
        tagged.append(sentence)

    joblib.dump(tagged, PATH + 'tagged_' + n + '.pkl')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:23                                                                                   │
# │                                                                                                  │
# │   20 │   # berita = berita.dropna(subset=['berita_desc'])                                        │
# │   21 │   # berita.sort_values('berita_desc', inplace=True)                                       │
# │   22 │   # berita.drop_duplicates(subset='berita_desc', keep=False, inplace=True)                │
# │ ❱ 23 │   df_train, df_test = train_test_split(berita, test_size=0.1, random_state=1)             │
# │   24 │   print(topik_id, n, len(df_test))                                                        │
# │   25 │   # find date                                                                             │
# ...
